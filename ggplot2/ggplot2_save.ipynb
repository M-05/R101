# %% [markdown]
# # [ggplot](https://ggplot2.tidyverse.org/)
# > Grammars of Graphics
#
# [ggplot 유튜브](https://www.youtube.com/watch?v=nd-sNVdmm8A&list=PLY0OaF78qqGCYlttTzLQufH3k9X2okgxo&index=15)
#
#
# ```
# install.packages("gridExtra")
# ```
#
# ```
# myggplot = grid.arrange(p1, p2, p3, p4, nrow=2, ncol=2)
#
# ggsave(file="myplot.png", plot=myggplot,
#         width=7.0, height=5.5) # default = inch 단위
#         # units=c("in", "cm", "mm", "px")
# ```

# %%
install.packages("car")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘numDeriv’, ‘SparseM’, ‘MatrixModels’, ‘minqa’, ‘nloptr’, ‘Rcpp’, ‘RcppEigen’, ‘carData’, ‘abind’, ‘pbkrtest’, ‘quantreg’, ‘lme4’

# %%
library(ggplot2)
library(car)
head(Salaries)
# Out:
#   rank      discipline yrs.since.phd yrs.service sex  salary
# 1 Prof      B          19            18          Male 139750
# 2 Prof      B          20            16          Male 173200
# 3 AsstProf  B           4             3          Male  79750
# 4 Prof      B          45            39          Male 115000
# 5 Prof      B          40            41          Male 141500
# 6 AssocProf B           6             6          Male  97000

# %%
ggplot(Salaries, aes(x=rank)) +
  geom_bar(fill="maroon")
# Out:
# plot without title

# %%
ggplot(Salaries, aes(x=salary)) +
  geom_histogram(fill="steelblue")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(Salaries, aes(x=yrs.since.phd, y=salary)) +
  geom_point(color="orange")
# Out:
# plot without title

# %%
ggplot(Salaries, aes(x=rank, y=salary)) +
  geom_boxplot(fill="mistyrose")
# Out:
# plot without title

# %%
install.packages("gridExtra")
library(gridExtra) # 메모리에 적재
grid.arrange()
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# Error in unit(rep(1, nrow), "null"): 'x' and 'units' must have length > 0
# Traceback:
#
# 1. grid.arrange()
# 2. arrangeGrob(...)
# 3. unit(rep(1, nrow), "null")
# 4. stop("'x' and 'units' must have length > 0")

# %%
p1=ggplot(Salaries, aes(x=rank)) +
  geom_bar(fill="maroon")
p2=ggplot(Salaries, aes(x=salary)) +
  geom_histogram(fill="steelblue")
p3=ggplot(Salaries, aes(x=yrs.since.phd, y=salary)) +
  geom_point(color="orange")
p4=ggplot(Salaries, aes(x=rank, y=salary)) +
  geom_boxplot(fill="mistyrose")

# %%
grid.arrange(p1, p2, p3, p4, nrow=2, ncol=2)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
myggplot = grid.arrange(p1, p2, p3, p4, nrow=2, ncol=2)

ggsave(file="myplot.png", plot=myggplot,
        width=7.0, height=5.5) # default = inch 단위
        # units=c("in", "cm", "mm", "px")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
?ggsave

# %%
ggplot(Salaries, aes(x=rank, y=salary)) +
  geom_boxplot()
ggsave(file="myplot_boxplot.png") # 가장 최근에 실행한 그래프 저장.
# Out:
# Saving 6.67 x 6.67 in image
# plot without title
